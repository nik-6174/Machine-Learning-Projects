# %%
import sys
sys.path.append("../src/")
import matplotlib.pyplot as plt
from dataset import BengaliDatasetTrain
import torch
# %matplotlib inline
import numpy as np

# %%
dataset = BengaliDatasetTrain(folds=[0, 1], img_height=137, img_width=236, mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))

# %%
len(dataset)
# Out:
# 80336

# %%
idx = 0
img = dataset[idx]['image']
print(dataset[idx]['grapheme_root'])
print(dataset[idx]['vowel_diacritic'])
print(dataset[idx]['consonant_diacritic'])
npimg = img.numpy()
plt.imshow(np.transpose(npimg, (1, 2, 0)))
# Out:
# tensor(38)
# tensor(1)
# tensor(2)
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.0151553..2.6399999].

# %%
import torch
print(torch.cuda.is_available())
print(torch.version.cuda)
# Out:
# Running cells with 'storefront-qgLcXNZc (Python 3.10.11)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/91735/.virtualenvs/storefront-qgLcXNZc/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
